# %%
import mne
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat # Not entirely sure how to import the raw .mat data
from mne_connectivity import spectral_connectivity_time
from mne_connectivity.viz import plot_sensors_connectivity
from mne.minimum_norm import apply_inverse_epochs, make_inverse_operator
from mne.viz import circular_layout
import autoreject

mat_data = loadmat("Matlab Files/609_Depression_REST.mat")

# %%
eeg_signal = mat_data['EEG']['data'][0,0]

sampling_rate =  mat_data['EEG']['srate'][0,0][0,0]

chanlocs = mat_data['EEG']['chanlocs'][0,0]
channel_names = [str(chan[0]) for chan in chanlocs['labels'][0]]

# %%
print(len(channel_names))
print(channel_names)
# Out:
# 66
# ['FP1', 'FPZ', 'FP2', 'AF3', 'AF4', 'F7', 'F5', 'F3', 'F1', 'FZ', 'F2', 'F4', 'F6', 'F8', 'FT7', 'FC5', 'FC3', 'FC1', 'FCZ', 'FC2', 'FC4', 'FC6', 'FT8', 'T7', 'C5', 'C3', 'C1', 'CZ', 'C2', 'C4', 'C6', 'T8', 'M1', 'TP7', 'CP5', 'CP3', 'CP1', 'CPZ', 'CP2', 'CP4', 'CP6', 'TP8', 'M2', 'P7', 'P5', 'P3', 'P1', 'PZ', 'P2', 'P4', 'P6', 'P8', 'PO7', 'PO5', 'PO3', 'POZ', 'PO4', 'PO6', 'PO8', 'CB1', 'O1', 'OZ', 'O2', 'CB2', 'HEOG', 'VEOG']

# %%
info = mne.create_info(ch_names=channel_names, sfreq=sampling_rate, ch_types=['eeg']*59+['misc']+['eeg']*3+['misc']+['eog']*2)

# %%
info.set_montage("standard_1020", match_case=False, on_missing='warn')
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: FP1, FPZ, FP2, AF3, AF4, F7, F5, F3, F1, FZ, F2, F4, F6, F8, ...
#  chs: 62 EEG, 2 misc, 2 EOG
#  custom_ref_applied: False
#  dig: 65 items (3 Cardinal, 62 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: unspecified
#  nchan: 66
#  projs: []
#  sfreq: 500.0 Hz
# >

# %%
raw = mne.io.RawArray(eeg_signal, info)
# Out:
# Creating RawArray with float64 data, n_channels=66, n_times=252860
#     Range : 0 ... 252859 =      0.000 ...   505.718 secs
# Ready.

# %% [markdown]
# raw.plot(scalings='auto')

# %%
# Let's work with theta data for now

filtered_data = raw.copy().filter(l_freq=1, h_freq=None)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up high-pass filter at 1 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Filter length: 1651 samples (3.302 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.0s

# %%
eog_evoked = mne.preprocessing.create_eog_epochs(filtered_data).average()
eog_evoked.apply_baseline(baseline=(None, -0.2))
eog_evoked.plot_joint();
# Out:
# Using EOG channels: HEOG, VEOG
# EOG channel index for this subject is: [64 65]
# Filtering the data to remove DC offset to help distinguish blinks from saccades
# Selecting channel HEOG for blink detection
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5000 samples (10.000 s)
#
# Now detecting blinks and generating corresponding events
# Found 65 significant peaks
# Number of EOG events detected: 65
# Not setting metadata
# 65 matching events found
# No baseline correction applied
# Using data from preloaded Raw for 65 events and 501 original time points ...
# 0 bad epochs dropped
# Applying baseline correction (mode: mean)
# No projector specified for this dataset. Please consider the method self.add_proj.

# %%
ecg_evoked = mne.preprocessing.create_ecg_epochs(filtered_data).average()
ecg_evoked.apply_baseline(baseline=(None, -0.2))
ecg_evoked.plot_joint();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ecg_evoked = mne.preprocessing.create_ecg_epochs(filtered_data).average()
#       2 ecg_evoked.apply_baseline(baseline=(None, -0.2))
#       3 ecg_evoked.plot_joint();
#
# File <decorator-gen-415>:12, in create_ecg_epochs(raw, ch_name, event_id, picks, tmin, tmax, l_freq, h_freq, reject, flat, baseline, preload, keep_ecg, reject_by_annotation, decim, verbose)
#
# File ~\anaconda3\envs\mne\Lib\site-packages\mne\preprocessing\ecg.py:425, in create_ecg_epochs(raw, ch_name, event_id, picks, tmin, tmax, l_freq, h_freq, reject, flat, baseline, preload, keep_ecg, reject_by_annotation, decim, verbose)
#     419 if keep_ecg and (has_ecg or not preload):
#     420     raise ValueError(
#     421         "keep_ecg can be True only if the ECG channel is "
#     422         "created synthetically and preload=True."
#     423     )
# --> 425 events, _, _, ecg = find_ecg_events(
#     426     raw,
#     427     ch_name=ch_name,
#     428     event_id=event_id,
#     429     l_freq=l_freq,
#     430     h_freq=h_freq,
#     431     return_ecg=True,
#     432     reject_by_annotation=reject_by_annotation,
#     433 )
#     435 picks = _picks_to_idx(raw.info, picks, "all", exclude=())
#     437 # create epochs around ECG events and baseline (important)
#
# File <decorator-gen-414>:12, in find_ecg_events(raw, event_id, ch_name, tstart, l_freq, h_freq, qrs_threshold, filter_length, return_ecg, reject_by_annotation, verbose)
#
# File ~\anaconda3\envs\mne\Lib\site-packages\mne\preprocessing\ecg.py:220, in find_ecg_events(***failed resolving arguments***)
#     218     ecg = raw.get_data(picks=idx_ecg)
#     219 else:
# --> 220     ecg, _ = _make_ecg(raw, start=None, stop=None)
#     221 assert ecg.ndim == 2 and ecg.shape[0] == 1
#     222 ecg = ecg[0]
#
# File <decorator-gen-416>:12, in _make_ecg(inst, start, stop, reject_by_annotation, verbose)
#
# File ~\anaconda3\envs\mne\Lib\site-packages\mne\preprocessing\ecg.py:489, in _make_ecg(inst, start, stop, reject_by_annotation, verbose)
#     487 """Create ECG signal from cross channel average."""
#     488 if not any(c in inst for c in ["mag", "grad"]):
# --> 489     raise ValueError(
#     490         "Generating an artificial ECG channel can only be done for MEG data"
#     491     )
#     492 for ch in ["mag", "grad"]:
#     493     if ch in inst:
#
# ValueError: Generating an artificial ECG channel can only be done for MEG data

# %%
raw.plot(scalings='auto', title='Unprocessed raw')
# Out:
# Using qt as 2D backend.

# %%
epochs = mne.make_fixed_length_epochs(filtered_data, duration = 3, preload = True)
ar = autoreject.AutoReject(random_state=42)
ar.fit(epochs)
# Out:
# Not setting metadata
# 168 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 168 events and 1500 original time points ...
# 0 bad epochs dropped
# Running autoreject on ch_type=eeg
#   0%|          | Creating augmented epochs : 0/62 [00:00<?,       ?it/s]
#   0%|          | Computing thresholds ... : 0/62 [00:00<?,       ?it/s]

# %%
epochs_ar, reject_log = ar.transform(epochs, return_log=True)

# %%
epochs_ar, reject_log = ar.transform(epochs, return_log=True)

# %%
evoked_bad = epochs[reject_log.bad_epochs].average()
plt.figure()
plt.plot(evoked_bad.times, evoked_bad.data.T*1e6, 'r', zorder = -1);
epochs_ar.average().plot(axes=plt.gca());

# %%
print(evoked_bad.times.shape)
print(evoked_bad.data.shape)

# %%
epochs[reject_log.bad_epochs].plot(scalings='auto', title='Bad epochs from first autoreject')

# %%
epochs_ar.plot(scalings='auto', title='Cleaned epochs from first autoreject')

# %%
ica=mne.preprocessing.ICA(max_iter='auto', random_state=42)
ica.fit(epochs[~reject_log.bad_epochs])
ica

# %%
print(ica.get_explained_variance_ratio(filtered_data))
ica.plot_sources(filtered_data.copy().pick('eeg'))

# %%
ica.plot_components();

# %%
# blinks + heartbeats
ica.exclude=[]
ica.plot_overlay(raw, picks="eeg");

# %%
ecg_indices, ecg_scores = ica.find_bads_ecg(filtered_data)
print(ecg_indices)
ica.plot_scores(ecg_scores);

# %%
eog_indices, eog_scores = ica.find_bads_eog(filtered_data)
print(eog_indices)
ica.plot_scores(eog_scores);

# %%
ica.exclude = ecg_indices+eog_indices+[25]

# %%
ica.plot_sources(ecg_evoked);

# %%
ica.plot_sources(eog_evoked);

# %%
filtered_data_clean = filtered_data.copy()

ica.apply(filtered_data_clean)

# %%
filtered_data_clean.plot(scalings='auto')

# %%
epochs = mne.make_fixed_length_epochs(filtered_data_clean, duration=2)
eeg_epochs=epochs.load_data().copy().pick('eeg')

# %%
min_freq = 4
max_freq = 7
freqs = np.linspace(min_freq, max_freq, 10)
con_time = spectral_connectivity_time(eeg_epochs, freqs, method='pli', average=True,mode='multitaper', n_cycles=freqs/2, fmin=min_freq, fmax=max_freq)

# %%
con_time_data = con_time.get_data(output='dense')

# %%
con_time_data.shape

# %%
plt.figure(figsize=(8,8))

# if con_time contains 3 data for each freq range of interest: con_plot = plt.imshow(con_time_array[:,:,2], cmap='binary')
con_plot = plt.imshow(np.mean(con_time_data, axis=2), cmap='magma')
plt.title('Spectral connectivity time')
plt.xticks(range(len(channel_names)), channel_names, fontsize=7, rotation=90)
plt.yticks(range(len(channel_names)), channel_names, fontsize=7)

plt.show();

# %%
plot_sensors_connectivity(epochs.info, con=np.mean(con_time_data, axis=2), picks='eeg')
# Out:
# Using pyvistaqt 3d backend.

# %%
filtered_data_clean=filtered_data_clean.filter(4,7)
mne.set_eeg_reference(filtered_data_clean, ref_channels='average', projection=True)

fsaverage_path = mne.datasets.fetch_fsaverage()
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 4 - 7 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 4.00
# - Lower transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 3.00 Hz)
# - Upper passband edge: 7.00 Hz
# - Upper transition bandwidth: 2.00 Hz (-6 dB cutoff frequency: 8.00 Hz)
# - Filter length: 825 samples (1.650 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.1s
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# 0 files missing from root.txt in C:\Users\fmava\Downloads\EEG Learning\MDD Dataset Practice
# 0 files missing from bem.txt in C:\Users\fmava\Downloads\EEG Learning\MDD Dataset Practice\fsaverage

# %%
src_space = mne.setup_source_space('fsaverage', 'ico3', add_dist='True')
# Out:
# Setting up the source space with the following parameters:
#
# SUBJECTS_DIR = C:\Users\fmava\Downloads\EEG Learning\MDD Dataset Practice
# Subject      = fsaverage
# Surface      = white
# Icosahedron subdivision grade 3
#
# >>> 1. Creating the source space...
#
# Doing the icosahedral vertex picking...
# Loading C:\Users\fmava\Downloads\EEG Learning\MDD Dataset Practice\fsaverage\surf\lh.white...
# Mapping lh fsaverage -> ico (3) ...
#     Warning: zero size triangles: [3 4]
#     Triangle neighbors and vertex normals...
# Loading geometry from C:\Users\fmava\Downloads\EEG Learning\MDD Dataset Practice\fsaverage\surf\lh.sphere...
# Setting up the triangulation for the decimated surface...
# loaded lh.white 642/163842 selected to source space (ico = 3)
#
# Loading C:\Users\fmava\Downloads\EEG Learning\MDD Dataset Practice\fsaverage\surf\rh.white...
# Mapping rh fsaverage -> ico (3) ...
#     Warning: zero size triangles: [3 4]
#     Triangle neighbors and vertex normals...
# Loading geometry from C:\Users\fmava\Downloads\EEG Learning\MDD Dataset Practice\fsaverage\surf\rh.sphere...
# Setting up the triangulation for the decimated surface...
# loaded rh.white 642/163842 selected to source space (ico = 3)
#
# Calculating source space distances (limit=inf mm)...
#     Computing patch statistics...
#     Patch information added...
#     Computing patch statistics...
#     Patch information added...
# You are now one step closer to computing the gain matrix

# %%
mne.viz.plot_bem('fsaverage', src=src_space);
# Out:
# Using surface: C:\Users\fmava\Downloads\EEG Learning\MDD Dataset Practice\fsaverage\bem\inner_skull.surf
# Using surface: C:\Users\fmava\Downloads\EEG Learning\MDD Dataset Practice\fsaverage\bem\outer_skull.surf
# Using surface: C:\Users\fmava\Downloads\EEG Learning\MDD Dataset Practice\fsaverage\bem\outer_skin.surf
# C:\Users\fmava\anaconda3\envs\mne\Lib\site-packages\mne\viz\utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNEFigure size 780x731.5 with 12 Axes>

# %%
bem_sol = mne.read_bem_solution('fsaverage/bem/fsaverage-5120-5120-5120-bem-sol.fif')
# Out:
# Loading surfaces...
#
# Loading the solution matrix...
#
# Three-layer model surfaces loaded.
# Loaded linear collocation BEM solution from C:\Users\fmava\Downloads\EEG Learning\MDD Dataset Practice\fsaverage\bem\fsaverage-5120-5120-5120-bem-sol.fif

# %%
fwd_solution = mne.make_forward_solution(filtered_data_clean.info, 'fsaverage', src_space, bem_sol)
# Out:
# Source space          : <SourceSpaces: [<surface (lh), n_vertices=163842, n_used=642>, <surface (rh), n_vertices=163842, n_used=642>] MRI (surface RAS) coords, subject 'fsaverage', ~32.7 MB>
# MRI -> head transform : C:\Users\fmava\anaconda3\envs\mne\Lib\site-packages\mne\data\fsaverage\fsaverage-trans.fif
# Measurement data      : instance of Info
# Conductor model   : instance of ConductorModel
# Accurate field computations
# Do computations in head coordinates
# Free source orientations
#
# Read 2 source spaces a total of 1284 active source locations
#
# Coordinate transformation: MRI (surface RAS) -> head
#     0.999994 0.003552 0.000202      -1.76 mm
#     -0.003558 0.998389 0.056626      31.09 mm
#     -0.000001 -0.056626 0.998395      39.60 mm
#     0.000000 0.000000 0.000000       1.00
#
# Read  62 EEG channels from info
# Head coordinate coil definitions created.
# Source spaces are now in head coordinates.
#
# Employing the head->MRI coordinate transform with the BEM model.
# BEM model instance of ConductorModel is now set up
#
# Source spaces are in head coordinates.
# Checking that the sources are inside the surface (will take a few...)
# Checking surface interior status for 642 points...
#     Found 152/642 points inside  an interior sphere of radius   47.7 mm
#     Found   0/642 points outside an exterior sphere of radius   98.3 mm
#     Found   0/490 points outside using surface Qhull
#     Found 360/490 points outside using solid angles
#     Total 282/642 points inside the surface
# Interior check completed in 294.9 ms
#     360 source space points omitted because they are outside the inner skull surface.
#     Computing patch statistics...
#     Patch information added...
# Checking surface interior status for 642 points...
#     Found 139/642 points inside  an interior sphere of radius   47.7 mm
#     Found   0/642 points outside an exterior sphere of radius   98.3 mm
#     Found   0/503 points outside using surface Qhull
#     Found 360/503 points outside using solid angles
#     Total 282/642 points inside the surface
# Interior check completed in 204.0 ms
#     360 source space points omitted because they are outside the inner skull surface.
#     Computing patch statistics...
#     Patch information added...
#
# Setting up for EEG...
# Computing EEG at 564 source locations (free orientations)...
#
# Finished.

# %%
noise_cov=mne.make_ad_hoc_cov(filtered_data_clean.info)

inv_operator = make_inverse_operator(filtered_data_clean.info, fwd_solution, noise_cov=noise_cov, depth=None, loose='auto', verbose=True)
# Out:
# Converting forward solution to surface orientation
#     Average patch normals will be employed in the rotation to the local surface coordinates....
#     Converting to surface-based source orientations...
#     [done]
# Computing inverse operator with 62 channels.
#     62 out of 62 channels remain after picking
# Selected 62 channels
# Applying loose dipole orientations to surface source spaces: 0.2
# Whitening the forward solution.
#     Created an SSP operator (subspace dimension = 1)
# Computing rank from covariance with rank=None
#     Using tolerance 5.5e-18 (2.2e-16 eps * 62 dim * 0.0004  max singular value)
#     Estimated rank (eeg): 61
#     EEG: rank 61 computed from 62 data channels with 1 projector
#     Setting small EEG eigenvalues to zero (without PCA)
# Creating the source covariance matrix
# Adjusting source covariance matrix.
# Computing SVD of whitened and weighted lead field matrix.
#     largest singular value = 4.87968
#     scaling factor to adjust the trace = 4.20586e+20 (nchan = 62 nzero = 1)

# %%
snr=1.0
lambda2=1.0/snr**2
mne.set_eeg_reference(eeg_epochs, ref_channels='average', projection=True)
stcs=apply_inverse_epochs(eeg_epochs, inv_operator, lambda2=lambda2)
# Out:
# EEG channel type selected for re-referencing
# Adding average EEG reference projection.
# 1 projection items deactivated
# Average reference projection was added, but has not been applied yet. Use the apply_proj method to apply it.
# Preparing the inverse operator for use...
#     Scaled noise and source covariance from nave = 1 to nave = 1
#     Created the regularized inverter
#     Created an SSP operator (subspace dimension = 1)
#     Created the whitener using a noise covariance matrix with rank 61 (1 small eigenvalues omitted)
#     Computing noise-normalization factors (dSPM)...
# [done]
# Picked 62 channels from the data
# Computing inverse...
#     Eigenleads need to be weighted ...
# Processing epoch : 1 / 248
# combining the current components...
# Processing epoch : 2 / 248
# combining the current components...
# Processing epoch : 3 / 248
# combining the current components...
# Processing epoch : 4 / 248
# combining the current components...
# Processing epoch : 5 / 248
# combining the current components...
# Processing epoch : 6 / 248
# combining the current components...
# Processing epoch : 7 / 248
# combining the current components...
# Processing epoch : 8 / 248
# combining the current components...
# Processing epoch : 9 / 248
# combining the current components...
# Processing epoch : 10 / 248
# combining the current components...
# Processing epoch : 11 / 248
# combining the current components...
# Processing epoch : 12 / 248
# combining the current components...
# Processing epoch : 13 / 248
# combining the current components...
# Processing epoch : 14 / 248
# combining the current components...
# Processing epoch : 15 / 248
# combining the current components...
# Processing epoch : 16 / 248
# combining the current components...
# Processing epoch : 17 / 248
# combining the current components...
# Processing epoch : 18 / 248
# combining the current components...
# Processing epoch : 19 / 248
# combining the current components...
# Processing epoch : 20 / 248
# combining the current components...
# Processing epoch : 21 / 248
# combining the current components...
# Processing epoch : 22 / 248
# combining the current components...
# Processing epoch : 23 / 248
# combining the current components...
# Processing epoch : 24 / 248
# combining the current components...
# Processing epoch : 25 / 248
# combining the current components...
# Processing epoch : 26 / 248
# combining the current components...
# Processing epoch : 27 / 248
# combining the current components...
# Processing epoch : 28 / 248
# combining the current components...
# Processing epoch : 29 / 248
# combining the current components...
# Processing epoch : 30 / 248
# combining the current components...
# Processing epoch : 31 / 248
# combining the current components...
# Processing epoch : 32 / 248
# combining the current components...
# Processing epoch : 33 / 248
# combining the current components...
# Processing epoch : 34 / 248
# combining the current components...
# Processing epoch : 35 / 248
# combining the current components...
# Processing epoch : 36 / 248
# combining the current components...
# Processing epoch : 37 / 248
# combining the current components...
# Processing epoch : 38 / 248
# combining the current components...
# Processing epoch : 39 / 248
# combining the current components...
# Processing epoch : 40 / 248
# combining the current components...
# Processing epoch : 41 / 248
# combining the current components...
# Processing epoch : 42 / 248
# combining the current components...
# Processing epoch : 43 / 248
# combining the current components...
# Processing epoch : 44 / 248
# combining the current components...
# Processing epoch : 45 / 248
# combining the current components...
# Processing epoch : 46 / 248
# combining the current components...
# Processing epoch : 47 / 248
# combining the current components...
# Processing epoch : 48 / 248
# combining the current components...
# Processing epoch : 49 / 248
# combining the current components...
# Processing epoch : 50 / 248
# combining the current components...
# Processing epoch : 51 / 248
# combining the current components...
# Processing epoch : 52 / 248
# combining the current components...
# Processing epoch : 53 / 248
# combining the current components...
# Processing epoch : 54 / 248
# combining the current components...
# Processing epoch : 55 / 248
# combining the current components...
# Processing epoch : 56 / 248
# combining the current components...
# Processing epoch : 57 / 248
# combining the current components...
# Processing epoch : 58 / 248
# combining the current components...
# Processing epoch : 59 / 248
# combining the current components...
# Processing epoch : 60 / 248
# combining the current components...
# Processing epoch : 61 / 248
# combining the current components...
# Processing epoch : 62 / 248
# combining the current components...
# Processing epoch : 63 / 248
# combining the current components...
# Processing epoch : 64 / 248
# combining the current components...
# Processing epoch : 65 / 248
# combining the current components...
# Processing epoch : 66 / 248
# combining the current components...
# Processing epoch : 67 / 248
# combining the current components...
# Processing epoch : 68 / 248
# combining the current components...
# Processing epoch : 69 / 248
# combining the current components...
# Processing epoch : 70 / 248
# combining the current components...
# Processing epoch : 71 / 248
# combining the current components...
# Processing epoch : 72 / 248
# combining the current components...
# Processing epoch : 73 / 248
# combining the current components...
# Processing epoch : 74 / 248
# combining the current components...
# Processing epoch : 75 / 248
# combining the current components...
# Processing epoch : 76 / 248
# combining the current components...
# Processing epoch : 77 / 248
# combining the current components...
# Processing epoch : 78 / 248
# combining the current components...
# Processing epoch : 79 / 248
# combining the current components...
# Processing epoch : 80 / 248
# combining the current components...
# Processing epoch : 81 / 248
# combining the current components...
# Processing epoch : 82 / 248
# combining the current components...
# Processing epoch : 83 / 248
# combining the current components...
# Processing epoch : 84 / 248
# combining the current components...
# Processing epoch : 85 / 248
# combining the current components...
# Processing epoch : 86 / 248
# combining the current components...
# Processing epoch : 87 / 248
# combining the current components...
# Processing epoch : 88 / 248
# combining the current components...
# Processing epoch : 89 / 248
# combining the current components...
# Processing epoch : 90 / 248
# combining the current components...
# Processing epoch : 91 / 248
# combining the current components...
# Processing epoch : 92 / 248
# combining the current components...
# Processing epoch : 93 / 248
# combining the current components...
# Processing epoch : 94 / 248
# combining the current components...
# Processing epoch : 95 / 248
# combining the current components...
# Processing epoch : 96 / 248
# combining the current components...
# Processing epoch : 97 / 248
# combining the current components...
# Processing epoch : 98 / 248
# combining the current components...
# Processing epoch : 99 / 248
# combining the current components...
# Processing epoch : 100 / 248
# combining the current components...
# Processing epoch : 101 / 248
# combining the current components...
# Processing epoch : 102 / 248
# combining the current components...
# Processing epoch : 103 / 248
# combining the current components...
# Processing epoch : 104 / 248
# combining the current components...
# Processing epoch : 105 / 248
# combining the current components...
# Processing epoch : 106 / 248
# combining the current components...
# Processing epoch : 107 / 248
# combining the current components...
# Processing epoch : 108 / 248
# combining the current components...
# Processing epoch : 109 / 248
# combining the current components...
# Processing epoch : 110 / 248
# combining the current components...
# Processing epoch : 111 / 248
# combining the current components...
# Processing epoch : 112 / 248
# combining the current components...
# Processing epoch : 113 / 248
# combining the current components...
# Processing epoch : 114 / 248
# combining the current components...
# Processing epoch : 115 / 248
# combining the current components...
# Processing epoch : 116 / 248
# combining the current components...
# Processing epoch : 117 / 248
# combining the current components...
# Processing epoch : 118 / 248
# combining the current components...
# Processing epoch : 119 / 248
# combining the current components...
# Processing epoch : 120 / 248
# combining the current components...
# Processing epoch : 121 / 248
# combining the current components...
# Processing epoch : 122 / 248
# combining the current components...
# Processing epoch : 123 / 248
# combining the current components...
# Processing epoch : 124 / 248
# combining the current components...
# Processing epoch : 125 / 248
# combining the current components...
# Processing epoch : 126 / 248
# combining the current components...
# Processing epoch : 127 / 248
# combining the current components...
# Processing epoch : 128 / 248
# combining the current components...
# Processing epoch : 129 / 248
# combining the current components...
# Processing epoch : 130 / 248
# combining the current components...
# Processing epoch : 131 / 248
# combining the current components...
# Processing epoch : 132 / 248
# combining the current components...
# Processing epoch : 133 / 248
# combining the current components...
# Processing epoch : 134 / 248
# combining the current components...
# Processing epoch : 135 / 248
# combining the current components...
# Processing epoch : 136 / 248
# combining the current components...
# Processing epoch : 137 / 248
# combining the current components...
# Processing epoch : 138 / 248
# combining the current components...
# Processing epoch : 139 / 248
# combining the current components...
# Processing epoch : 140 / 248
# combining the current components...
# Processing epoch : 141 / 248
# combining the current components...
# Processing epoch : 142 / 248
# combining the current components...
# Processing epoch : 143 / 248
# combining the current components...
# Processing epoch : 144 / 248
# combining the current components...
# Processing epoch : 145 / 248
# combining the current components...
# Processing epoch : 146 / 248
# combining the current components...
# Processing epoch : 147 / 248
# combining the current components...
# Processing epoch : 148 / 248
# combining the current components...
# Processing epoch : 149 / 248
# combining the current components...
# Processing epoch : 150 / 248
# combining the current components...
# Processing epoch : 151 / 248
# combining the current components...
# Processing epoch : 152 / 248
# combining the current components...
# Processing epoch : 153 / 248
# combining the current components...
# Processing epoch : 154 / 248
# combining the current components...
# Processing epoch : 155 / 248
# combining the current components...
# Processing epoch : 156 / 248
# combining the current components...
# Processing epoch : 157 / 248
# combining the current components...
# Processing epoch : 158 / 248
# combining the current components...
# Processing epoch : 159 / 248
# combining the current components...
# Processing epoch : 160 / 248
# combining the current components...
# Processing epoch : 161 / 248
# combining the current components...
# Processing epoch : 162 / 248
# combining the current components...
# Processing epoch : 163 / 248
# combining the current components...
# Processing epoch : 164 / 248
# combining the current components...
# Processing epoch : 165 / 248
# combining the current components...
# Processing epoch : 166 / 248
# combining the current components...
# Processing epoch : 167 / 248
# combining the current components...
# Processing epoch : 168 / 248
# combining the current components...
# Processing epoch : 169 / 248
# combining the current components...
# Processing epoch : 170 / 248
# combining the current components...
# Processing epoch : 171 / 248
# combining the current components...
# Processing epoch : 172 / 248
# combining the current components...
# Processing epoch : 173 / 248
# combining the current components...
# Processing epoch : 174 / 248
# combining the current components...
# Processing epoch : 175 / 248
# combining the current components...
# Processing epoch : 176 / 248
# combining the current components...
# Processing epoch : 177 / 248
# combining the current components...
# Processing epoch : 178 / 248
# combining the current components...
# Processing epoch : 179 / 248
# combining the current components...
# Processing epoch : 180 / 248
# combining the current components...
# Processing epoch : 181 / 248
# combining the current components...
# Processing epoch : 182 / 248
# combining the current components...
# Processing epoch : 183 / 248
# combining the current components...
# Processing epoch : 184 / 248
# combining the current components...
# Processing epoch : 185 / 248
# combining the current components...
# Processing epoch : 186 / 248
# combining the current components...
# Processing epoch : 187 / 248
# combining the current components...
# Processing epoch : 188 / 248
# combining the current components...
# Processing epoch : 189 / 248
# combining the current components...
# Processing epoch : 190 / 248
# combining the current components...
# Processing epoch : 191 / 248
# combining the current components...
# Processing epoch : 192 / 248
# combining the current components...
# Processing epoch : 193 / 248
# combining the current components...
# Processing epoch : 194 / 248
# combining the current components...
# Processing epoch : 195 / 248
# combining the current components...
# Processing epoch : 196 / 248
# combining the current components...
# Processing epoch : 197 / 248
# combining the current components...
# Processing epoch : 198 / 248
# combining the current components...
# Processing epoch : 199 / 248
# combining the current components...
# Processing epoch : 200 / 248
# combining the current components...
# Processing epoch : 201 / 248
# combining the current components...
# Processing epoch : 202 / 248
# combining the current components...
# Processing epoch : 203 / 248
# combining the current components...
# Processing epoch : 204 / 248
# combining the current components...
# Processing epoch : 205 / 248
# combining the current components...
# Processing epoch : 206 / 248
# combining the current components...
# Processing epoch : 207 / 248
# combining the current components...
# Processing epoch : 208 / 248
# combining the current components...
# Processing epoch : 209 / 248
# combining the current components...
# Processing epoch : 210 / 248
# combining the current components...
# Processing epoch : 211 / 248
# combining the current components...
# Processing epoch : 212 / 248
# combining the current components...
# Processing epoch : 213 / 248
# combining the current components...
# Processing epoch : 214 / 248
# combining the current components...
# Processing epoch : 215 / 248
# combining the current components...
# Processing epoch : 216 / 248
# combining the current components...
# Processing epoch : 217 / 248
# combining the current components...
# Processing epoch : 218 / 248
# combining the current components...
# Processing epoch : 219 / 248
# combining the current components...
# Processing epoch : 220 / 248
# combining the current components...
# Processing epoch : 221 / 248
# combining the current components...
# Processing epoch : 222 / 248
# combining the current components...
# Processing epoch : 223 / 248
# combining the current components...
# Processing epoch : 224 / 248
# combining the current components...
# Processing epoch : 225 / 248
# combining the current components...
# Processing epoch : 226 / 248
# combining the current components...
# Processing epoch : 227 / 248
# combining the current components...
# Processing epoch : 228 / 248
# combining the current components...
# Processing epoch : 229 / 248
# combining the current components...
# Processing epoch : 230 / 248
# combining the current components...
# Processing epoch : 231 / 248
# combining the current components...
# Processing epoch : 232 / 248
# combining the current components...
# Processing epoch : 233 / 248
# combining the current components...
# Processing epoch : 234 / 248
# combining the current components...
# Processing epoch : 235 / 248
# combining the current components...
# Processing epoch : 236 / 248
# combining the current components...
# Processing epoch : 237 / 248
# combining the current components...
# Processing epoch : 238 / 248
# combining the current components...
# Processing epoch : 239 / 248
# combining the current components...
# Processing epoch : 240 / 248
# combining the current components...
# Processing epoch : 241 / 248
# combining the current components...
# Processing epoch : 242 / 248
# combining the current components...
# Processing epoch : 243 / 248
# combining the current components...
# Processing epoch : 244 / 248
# combining the current components...
# Processing epoch : 245 / 248
# combining the current components...
# Processing epoch : 246 / 248
# combining the current components...
# Processing epoch : 247 / 248
# combining the current components...
# Processing epoch : 248 / 248
# combining the current components...
# [done]

# %%
labels=mne.read_labels_from_annot('fsaverage')
label_colors=[label.color for label in labels]
label_names=[label.name for label in labels]
lh_labels=[name for name in label_names if name.endswith('lh')]
rh_labels=[name for name in label_names if name.endswith('rh')]

label_ypos=list()
for name in lh_labels:
    idx=label_names.index(name)
    ypos=np.mean(labels[idx].pos[:,1])
    label_ypos.append(ypos)

# Reorder the labels based on their location
lh_labels = [label for (yp, label) in sorted(zip(label_ypos, lh_labels))]
rh_labels = [label for (yp, label) in sorted(zip(label_ypos, rh_labels))]
# Out:
# Reading labels from parcellation...
#    read 35 labels from C:\Users\fmava\Downloads\EEG Learning\MDD Dataset Practice\fsaverage\label\lh.aparc.annot
#    read 34 labels from C:\Users\fmava\Downloads\EEG Learning\MDD Dataset Practice\fsaverage\label\rh.aparc.annot

# %%
print(len(lh_labels), len(rh_labels))
# Out:
# 35 34

# %%
inv_operator['src']
# Out:
# <SourceSpaces: [<surface (lh), n_vertices=163842, n_used=282>, <surface (rh), n_vertices=163842, n_used=282>] head coords, subject 'fsaverage', ~42.1 MB>

# %%
# Filter out labels that have no vertices in the source space
valid_labels = []
lh_vertices=inv_operator['src'][0]['vertno']
rh_vertices=inv_operator['src'][1]['vertno']

for label in labels:
    label_vertices=label.vertices
    if any(v in lh_vertices for v in label_vertices) or any(v in rh_vertices for v in label_vertices):
        valid_labels.append(label)

# %%
print(len(labels))
print(len(valid_labels))
# Out:
# 69
# 63

# %%
# Ok, I'm still getting an error saying 'bankssts-lh', 'inferiortemporal-lh' don't contain vertices, so 
# I don't care anymore, I'm just gonna remove them manually

# Define the labels to remove manually (those causing the error)
labels_to_remove = ['bankssts-lh','inferiortemporal-lh']

# Manually filter out labels that are in the `labels_to_remove` list
valid_labels = [label for label in valid_labels if label.name not in labels_to_remove]

# %%
print(len(labels))
print(len(valid_labels))
# Out:
# 69
# 61

# %%
label_ts=mne.extract_label_time_course(
    stcs, valid_labels, src=inv_operator['src'], mode="mean_flip", return_generator=True
)

# %%
from mne_connectivity import spectral_connectivity_epochs

label_cons = spectral_connectivity_epochs(
    label_ts,
    method='pli',
    mode="multitaper",
    fmin=3,
    fmax=7,
    sfreq=filtered_data_clean.info['sfreq'],
    faverage=True,
    mt_adaptive=True,
)
# Out:
# Connectivity computation...
# Extracting time courses for 61 labels (mode: mean_flip)
# only using indices for lower-triangular matrix
#     computing connectivity for 1830 connections
#     using t=0.000s..1.998s for estimation (1000 points)
#     frequencies: 3.0Hz..7.0Hz (9 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: PLI
#     computing cross-spectral density for epoch 1
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 2
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 3
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 4
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 5
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 6
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 7
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 8
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 9
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 10
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 11
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 12
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 13
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 14
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 15
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 16
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 17
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 18
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 19
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 20
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 21
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 22
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 23
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 24
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 25
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 26
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 27
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 28
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 29
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 30
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 31
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 32
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 33
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 34
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 35
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 36
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 37
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 38
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 39
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 40
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 41
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 42
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 43
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 44
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 45
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 46
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 47
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 48
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 49
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 50
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 51
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 52
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 53
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 54
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 55
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 56
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 57
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 58
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 59
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 60
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 61
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 62
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 63
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 64
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 65
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 66
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 67
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 68
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 69
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 70
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 71
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 72
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 73
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 74
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 75
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 76
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 77
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 78
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 79
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 80
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 81
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 82
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 83
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 84
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 85
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 86
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 87
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 88
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 89
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 90
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 91
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 92
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 93
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 94
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 95
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 96
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 97
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 98
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 99
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 100
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 101
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 102
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 103
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 104
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 105
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 106
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 107
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 108
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 109
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 110
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 111
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 112
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 113
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 114
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 115
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 116
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 117
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 118
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 119
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 120
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 121
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 122
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 123
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 124
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 125
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 126
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 127
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 128
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 129
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 130
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 131
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 132
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 133
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 134
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 135
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 136
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 137
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 138
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 139
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 140
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 141
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 142
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 143
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 144
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 145
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 146
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 147
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 148
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 149
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 150
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 151
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 152
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 153
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 154
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 155
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 156
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 157
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 158
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 159
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 160
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 161
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 162
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 163
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 164
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 165
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 166
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 167
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 168
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 169
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 170
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 171
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 172
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 173
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 174
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 175
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 176
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 177
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 178
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 179
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 180
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 181
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 182
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 183
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 184
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 185
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 186
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 187
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 188
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 189
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 190
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 191
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 192
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 193
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 194
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 195
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 196
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 197
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 198
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 199
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 200
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 201
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 202
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 203
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 204
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 205
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 206
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 207
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 208
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 209
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 210
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 211
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 212
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 213
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 214
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 215
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 216
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 217
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 218
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 219
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 220
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 221
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 222
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 223
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 224
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 225
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 226
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 227
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 228
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 229
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 230
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 231
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 232
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 233
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 234
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 235
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 236
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 237
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 238
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 239
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 240
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 241
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 242
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 243
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 244
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 245
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 246
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 247
# Extracting time courses for 61 labels (mode: mean_flip)
#     computing cross-spectral density for epoch 248
#     assembling connectivity matrix
# [Connectivity computation done]

# %%
label_cons_data = label_cons.get_data(output='dense').mean(axis=2)

# %%
print(label_cons_data.shape)
print(len(valid_labels))
# Out:
# (61, 61)
# 61

# %%
valid_label_names = [label.name for label in valid_labels]
lh_labels=[name for name in valid_label_names if name.endswith('lh')]
rh_labels=[name for name in valid_label_names if not (name.endswith('lh'))]

label_ypos=list()
for name in lh_labels:
    idx=label_names.index(name)
    ypos=np.mean(labels[idx].pos[:,1])
    label_ypos.append(ypos)

# Reorder the labels based on their location
lh_labels = [label for label in sorted(lh_labels)]
rh_labels = [label for label in sorted(rh_labels)]

# %%
print(len(node_order))
print(len(valid_labels))
print(len(lh_labels), len(rh_labels))
print(len(valid_label_names))
print(len(node_angles))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 print(len(node_order))
#       2 print(len(valid_labels))
#       3 print(len(lh_labels), len(rh_labels))
#
# NameError: name 'node_order' is not defined

# %%
from mne_connectivity.viz import plot_connectivity_circle

# Save the plot order and create a circular layout
node_order = list()
node_order.extend(lh_labels[::-1])  # reverse the order
node_order.extend(rh_labels)

node_angles = circular_layout(
    valid_label_names, node_order, start_pos=90, group_boundaries=[0, len(valid_labels) / 2]
)

con_square_matrix=np.mean(con_time_data, axis=2)

# Plot the graph using node colors from the FreeSurfer parcellation. We only
# show the 300 strongest connections.
fig, ax = plt.subplots(figsize=(8, 8), facecolor="black", subplot_kw=dict(polar=True))

plot_connectivity_circle(
    con=label_cons_data,
    node_names=valid_label_names,
    n_lines=300,
    node_angles=node_angles,
    node_colors=label_colors,
    title="All-to-All Connectivity" "Condition (PLI)",
    ax=ax,
)
fig.tight_layout()
